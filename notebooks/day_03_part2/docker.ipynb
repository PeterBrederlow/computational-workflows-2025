# %% [markdown]
# # A short introduction to containerized software
#
# After spending time using nf-core pipelines to answer bioinformatic questions, we will focus on the processes that lie behind these pipelines now.
#
# Today, we will focus on containerization, namely via Docker.

# %% [markdown]
# 1. Check if Docker is installed.

# %%
# !docker info
# Out:
# Client:
#  Version:    28.4.0
#  Context:    desktop-linux
#  Debug Mode: false
#  Plugins:
#   ai: Docker AI Agent - Ask Gordon (Docker Inc.)
#     Version:  v1.9.11
#     Path:     /Users/peterbrederlow/.docker/cli-plugins/docker-ai
#   buildx: Docker Buildx (Docker Inc.)
#     Version:  v0.28.0-desktop.1
#     Path:     /Users/peterbrederlow/.docker/cli-plugins/docker-buildx
#   cloud: Docker Cloud (Docker Inc.)
#     Version:  v0.4.29
#     Path:     /Users/peterbrederlow/.docker/cli-plugins/docker-cloud
#   compose: Docker Compose (Docker Inc.)
#     Version:  v2.39.4-desktop.1
#     Path:     /Users/peterbrederlow/.docker/cli-plugins/docker-compose
#   debug: Get a shell into any image or container (Docker Inc.)
#     Version:  0.0.42
#     Path:     /Users/peterbrederlow/.docker/cli-plugins/docker-debug
#   desktop: Docker Desktop commands (Docker Inc.)
#     Version:  v0.2.0
#     Path:     /Users/peterbrederlow/.docker/cli-plugins/docker-desktop
#   extension: Manages Docker extensions (Docker Inc.)
#     Version:  v0.2.31
#     Path:     /Users/peterbrederlow/.docker/cli-plugins/docker-extension
#   init: Creates Docker-related starter files for your project (Docker Inc.)
#     Version:  v1.4.0
#     Path:     /Users/peterbrederlow/.docker/cli-plugins/docker-init
#   mcp: Docker MCP Plugin (Docker Inc.)
#     Version:  v0.21.0
#     Path:     /Users/peterbrederlow/.docker/cli-plugins/docker-mcp
#   model: Docker Model Runner (Docker Inc.)
#     Version:  v0.1.41
#     Path:     /Users/peterbrederlow/.docker/cli-plugins/docker-model
#   sbom: View the packaged-based Software Bill Of Materials (SBOM) for an image (Anchore Inc.)
#     Version:  0.6.0
#     Path:     /Users/peterbrederlow/.docker/cli-plugins/docker-sbom
#   scout: Docker Scout (Docker Inc.)
#     Version:  v1.18.3
#     Path:     /Users/peterbrederlow/.docker/cli-plugins/docker-scout
#
# Server:
#  Containers: 2
#   Running: 0
#   Paused: 0
#   Stopped: 2
#  Images: 13
#  Server Version: 28.4.0
#  Storage Driver: overlayfs
#   driver-type: io.containerd.snapshotter.v1
#  Logging Driver: json-file
#  Cgroup Driver: cgroupfs
#  Cgroup Version: 2
#  Plugins:
#   Volume: local
#   Network: bridge host ipvlan macvlan null overlay
#   Log: awslogs fluentd gcplogs gelf journald json-file local splunk syslog
#  CDI spec directories:
#   /etc/cdi
#   /var/run/cdi
#  Swarm: inactive
#  Runtimes: io.containerd.runc.v2 runc
#  Default Runtime: runc
#  Init Binary: docker-init
#  containerd version: 05044ec0a9a75232cad458027ca83437aae3f4da
#  runc version: v1.2.5-0-g59923ef
#  init version: de40ad0
#  Security Options:
#   seccomp
#    Profile: builtin
#   cgroupns
#  Kernel Version: 6.10.14-linuxkit
#  Operating System: Docker Desktop
#  OSType: linux
#  Architecture: aarch64
#  CPUs: 11
#  Total Memory: 7.654GiB
#  Name: docker-desktop
#  ID: dfc11284-506d-4a4b-bcf2-80cf94671e96
#  Docker Root Dir: /var/lib/docker
#  Debug Mode: false
#  HTTP Proxy: http.docker.internal:3128
#  HTTPS Proxy: http.docker.internal:3128
#  No Proxy: hubproxy.docker.internal
#  Labels:
#   com.docker.desktop.address=unix:///Users/peterbrederlow/Library/Containers/com.docker.docker/Data/docker-cli.sock
#  Experimental: false
#  Insecure Registries:
#   hubproxy.docker.internal:5555
#   ::1/128
#   127.0.0.0/8
#  Live Restore Enabled: false

# %% [markdown]
# ### What is a container?

# %% [markdown]
# A cointainer is an isolated packaged application that runs with the hosts kernel.
#
# Source: What is a container? | Docker Docs. (n.d.). Retrieved October 1, 2025, from https://docs.docker.com/get-started/docker-concepts/the-basics/what-is-a-container/

# %% [markdown]
# ### Why do we use containers?

# %% [markdown]
# To prevent dependency issues due to differing software versions needed for different steps in the pipeline. Like that, all processes run with their needed versions.

# %% [markdown]
# ### What is a docker image?

# %% [markdown]
# A docker image is a standardized package that includes all of the files, binaries, libraries, and configurations to run a container.
#
# Source: What is an image? | Docker Docs. (n.d.). Retrieved October 1, 2025, from https://docs.docker.com/get-started/docker-concepts/the-basics/what-is-an-image/

# %% [markdown]
# ### Let's run our first docker image:

# %% [markdown]
# ### Run your first docker container

# %%
# !docker run hello-world
# Out:
# Hello from Docker!
# This message shows that your installation appears to be working correctly.
#
# To generate this message, Docker took the following steps:
#  1. The Docker client contacted the Docker daemon.
#  2. The Docker daemon pulled the "hello-world" image from the Docker Hub.
#     (arm64v8)
#  3. The Docker daemon created a new container from that image which runs the
#     executable that produces the output you are currently reading.
#  4. The Docker daemon streamed that output to the Docker client, which sent it
#     to your terminal.
#
# To try something more ambitious, you can run an Ubuntu container with:
#  $ docker run -it ubuntu bash
#
# Share images, automate workflows, and more with a free Docker ID:
#  https://hub.docker.com/
#
# For more examples and ideas, visit:
#  https://docs.docker.com/get-started/

# %% [markdown]
# ### Find the container ID

# %%
# !docker ps -a
# Out:
# CONTAINER ID   IMAGE         COMMAND    CREATED          STATUS                      PORTS     NAMES
# 2d0d5a48311c   hello-world   "/hello"   1 second ago     Exited (0) 1 second ago               quirky_bohr
# a8274af1edab   hello-world   "/hello"   12 minutes ago   Exited (0) 12 minutes ago             nervous_taussig
# da03790567b5   hello-world   "/hello"   5 days ago       Exited (0) 5 days ago                 relaxed_spence

# %% [markdown]
# ### Delete the container again, give prove its deleted

# %%
# !docker rm 2d0d5a48311c
# Out:
# 2d0d5a48311c

# %%
# !docker ps -a
# Out:
# CONTAINER ID   IMAGE         COMMAND    CREATED          STATUS                      PORTS     NAMES
# a8274af1edab   hello-world   "/hello"   16 minutes ago   Exited (0) 16 minutes ago             nervous_taussig
# da03790567b5   hello-world   "/hello"   5 days ago       Exited (0) 5 days ago                 relaxed_spence

# %% [markdown]
# ### FASTQC is a very useful tool as you've learned last week. Let's try and run it from command line
#
# Link to the software: https://www.bioinformatics.babraham.ac.uk/projects/fastqc/

# %% [markdown]
# Please describe the steps you took to download and run the software for the example fastq file from last week below:

# %% [markdown]
# 1. first we looked for the correct nf-core pipeline
# 2. then we ran the pipeline using nextflow
# ...

# %% [markdown]
# ### Very well, now let's try to make use of its docker container
#
# 1. create a container holding fastqc using seqera containers (https://seqera.io/containers/)
# 2. use the container to generate a fastqc html of the example fastq file

# %%
# pull the container
# !docker pull community.wave.seqera.io/library/fastqc:0.12.1--af7a5314d5015c29
# Out:
# 0.12.1--af7a5314d5015c29: Pulling from library/fastqc
#
# 2b0c44d2: Pulling fs layer
# a01cff0b: Pulling fs layer
# 7ea432cc: Pulling fs layer
# 47592a0a: Pulling fs layer
# 74b0f85e: Pulling fs layer
# b700ef54: Pulling fs layer
# d6c3110d: Pulling fs layer
# 97a3ef36: Pulling fs layer
# c00c10a5: Pulling fs layer
# b097362e: Pulling fs layer
# a16bbe82: Pulling fs layer
# b700ef54: Pulling fs layer
# Digest: sha256:b7f6caf359264cf86da901b0aa5f66735a6506fcfbf103c66db6987253ad44c113A
# Status: Downloaded newer image for community.wave.seqera.io/library/fastqc:0.12.1--af7a5314d5015c29
# community.wave.seqera.io/library/fastqc:0.12.1--af7a5314d5015c29

# %%
# run the container and save the results to a new "fastqc_results" directory
# !docker run \
    -v "/Users/peterbrederlow/Documents/Uni/MasterBioinformatik/SS25/WorkflowCourse/computational-workflows-2025/":/data \
    community.wave.seqera.io/library/fastqc:0.12.1--af7a5314d5015c29 \
    fastqc /data/SRFetch_results/fastq/SRX19144486_SRR23195516_2.fastq.gz \
    -o /data/dockertests
# Out:
# WARNING: The requested image's platform (linux/amd64) does not match the detected host platform (linux/arm64/v8) and no specific platform was requested
# application/gzip
# Started analysis of SRX19144486_SRR23195516_2.fastq.gz
# Approx 5% complete for SRX19144486_SRR23195516_2.fastq.gz
# Approx 10% complete for SRX19144486_SRR23195516_2.fastq.gz
# Approx 15% complete for SRX19144486_SRR23195516_2.fastq.gz
# Approx 20% complete for SRX19144486_SRR23195516_2.fastq.gz
# Approx 25% complete for SRX19144486_SRR23195516_2.fastq.gz
# Approx 30% complete for SRX19144486_SRR23195516_2.fastq.gz
# Approx 35% complete for SRX19144486_SRR23195516_2.fastq.gz
# Approx 40% complete for SRX19144486_SRR23195516_2.fastq.gz
# Approx 45% complete for SRX19144486_SRR23195516_2.fastq.gz
# Approx 50% complete for SRX19144486_SRR23195516_2.fastq.gz
# Approx 55% complete for SRX19144486_SRR23195516_2.fastq.gz
# Approx 60% complete for SRX19144486_SRR23195516_2.fastq.gz
# Approx 65% complete for SRX19144486_SRR23195516_2.fastq.gz
# Approx 70% complete for SRX19144486_SRR23195516_2.fastq.gz
# Approx 75% complete for SRX19144486_SRR23195516_2.fastq.gz
# Approx 80% complete for SRX19144486_SRR23195516_2.fastq.gz
# Approx 85% complete for SRX19144486_SRR23195516_2.fastq.gz
# Approx 90% complete for SRX19144486_SRR23195516_2.fastq.gz
# Approx 95% complete for SRX19144486_SRR23195516_2.fastq.gz
# Analysis complete for SRX19144486_SRR23195516_2.fastq.gz

# %% [markdown]
# ### Now that you know how to use a docker container, which approach was easier and which approach will be easier in the future?

# %% [markdown]
# Definitely the nextflow path, since it automatically pulled the docker containers and specified the directories.

# %% [markdown]
# ### What would you say, which approach is more reproducible?

# %% [markdown]
# Also the nextflow pipeline using docker as a profile, since the installed containers are reproducible.

# %% [markdown]
# ### Compare the file to last weeks fastqc results, are they identical?
# ### Is the fastqc version identical?

# %% [markdown]
# Yes, it is identical. The version is 0.12.1 in both cases.

# %% [markdown]
# ## Dockerfiles
#
# We now used Docker containers and images directly to boost our research.
#
# Let's create our own toy Dockerfile including the "cowsay" tool (https://en.wikipedia.org/wiki/Cowsay)
#
# Hints:
# 1. Docker is Linux, so you need to know the apt-get command to install "cowsay"

# %%
# open the file "my_dockerfile" in a text edit
# !TODO: add the command that is run to install the dependencies for the image. In this case, it should be updating the package list and installing curl and cowsay.
RUN apt-update
RUN apt-get --yes install curl cowsay

# %% [markdown]
# ### Explain the RUN and ENV lines you added to the file

# %%
# build the docker image
# !docker build -t cowshoutimage -f /Users/peterbrederlow/Documents/Uni/MasterBioinformatik/SS25/WorkflowCourse/computational-workflows-2025/notebooks/day_03_part2/my_dockerfile .
# Out:
# [+] Building 0.0s (0/1)                                    docker:desktop-linux
# [+] Building 0.1s (1/3)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 901B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.1s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
# [+] Building 0.3s (2/3)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 901B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.3s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
# [+] Building 0.4s (2/3)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 901B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.4s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
# [+] Building 0.6s (2/3)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 901B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.6s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
# [+] Building 0.7s (2/3)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 901B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.7s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
# [+] Building 0.9s (2/3)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 901B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.9s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
# [+] Building 0.9s (3/3)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 901B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.9s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
# [+] Building 1.1s (5/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 901B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.9s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/2] RUN apt-get update &&     apt-get install -y curl cowsay &&      0.1s
#  => => # Get:1 http://deb.debian.org/debian bullseye InRelease [75.1 kB]
# [+] Building 1.2s (5/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 901B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.9s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/2] RUN apt-get update &&     apt-get install -y curl cowsay &&      0.3s
#  => => # Get:2 http://deb.debian.org/debian-security bullseye-security InReleas
#  => => # e [27.2 kB]
#  => => # Get:3 http://deb.debian.org/debian bullseye-updates InRelease [44.0 kB
#  => => # ]
#  => => # Get:4 http://deb.debian.org/debian bullseye/main arm64 Packages [7955
#  => => # kB]
# [+] Building 1.3s (5/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 901B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.9s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/2] RUN apt-get update &&     apt-get install -y curl cowsay &&      0.4s
#  => => # Get:2 http://deb.debian.org/debian-security bullseye-security InReleas
#  => => # e [27.2 kB]
#  => => # Get:3 http://deb.debian.org/debian bullseye-updates InRelease [44.0 kB
#  => => # ]
#  => => # Get:4 http://deb.debian.org/debian bullseye/main arm64 Packages [7955
#  => => # kB]
# [+] Building 1.5s (5/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 901B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.9s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/2] RUN apt-get update &&     apt-get install -y curl cowsay &&      0.6s
#  => => # Get:2 http://deb.debian.org/debian-security bullseye-security InReleas
#  => => # e [27.2 kB]
#  => => # Get:3 http://deb.debian.org/debian bullseye-updates InRelease [44.0 kB
#  => => # ]
#  => => # Get:4 http://deb.debian.org/debian bullseye/main arm64 Packages [7955
#  => => # kB]
# [+] Building 1.6s (5/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 901B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.9s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/2] RUN apt-get update &&     apt-get install -y curl cowsay &&      0.7s
#  => => # Get:2 http://deb.debian.org/debian-security bullseye-security InReleas
#  => => # e [27.2 kB]
#  => => # Get:3 http://deb.debian.org/debian bullseye-updates InRelease [44.0 kB
#  => => # ]
#  => => # Get:4 http://deb.debian.org/debian bullseye/main arm64 Packages [7955
#  => => # kB]
# [+] Building 1.8s (5/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 901B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.9s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/2] RUN apt-get update &&     apt-get install -y curl cowsay &&      0.9s
#  => => # Get:2 http://deb.debian.org/debian-security bullseye-security InReleas
#  => => # e [27.2 kB]
#  => => # Get:3 http://deb.debian.org/debian bullseye-updates InRelease [44.0 kB
#  => => # ]
#  => => # Get:4 http://deb.debian.org/debian bullseye/main arm64 Packages [7955
#  => => # kB]
# [+] Building 1.9s (5/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 901B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.9s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/2] RUN apt-get update &&     apt-get install -y curl cowsay &&      1.0s
#  => => # Get:2 http://deb.debian.org/debian-security bullseye-security InReleas
#  => => # e [27.2 kB]
#  => => # Get:3 http://deb.debian.org/debian bullseye-updates InRelease [44.0 kB
#  => => # ]
#  => => # Get:4 http://deb.debian.org/debian bullseye/main arm64 Packages [7955
#  => => # kB]
# [+] Building 2.1s (5/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 901B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.9s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/2] RUN apt-get update &&     apt-get install -y curl cowsay &&      1.2s
#  => => # Get:2 http://deb.debian.org/debian-security bullseye-security InReleas
#  => => # e [27.2 kB]
#  => => # Get:3 http://deb.debian.org/debian bullseye-updates InRelease [44.0 kB
#  => => # ]
#  => => # Get:4 http://deb.debian.org/debian bullseye/main arm64 Packages [7955
#  => => # kB]
# [+] Building 2.2s (5/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 901B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.9s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/2] RUN apt-get update &&     apt-get install -y curl cowsay &&      1.3s
#  => => # Get:2 http://deb.debian.org/debian-security bullseye-security InReleas
#  => => # e [27.2 kB]
#  => => # Get:3 http://deb.debian.org/debian bullseye-updates InRelease [44.0 kB
#  => => # ]
#  => => # Get:4 http://deb.debian.org/debian bullseye/main arm64 Packages [7955
#  => => # kB]
# [+] Building 2.4s (5/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 901B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.9s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/2] RUN apt-get update &&     apt-get install -y curl cowsay &&      1.5s
#  => => # Get:2 http://deb.debian.org/debian-security bullseye-security InReleas
#  => => # e [27.2 kB]
#  => => # Get:3 http://deb.debian.org/debian bullseye-updates InRelease [44.0 kB
#  => => # ]
#  => => # Get:4 http://deb.debian.org/debian bullseye/main arm64 Packages [7955
#  => => # kB]
# [+] Building 2.5s (5/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 901B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.9s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/2] RUN apt-get update &&     apt-get install -y curl cowsay &&      1.6s
#  => => # Get:2 http://deb.debian.org/debian-security bullseye-security InReleas
#  => => # e [27.2 kB]
#  => => # Get:3 http://deb.debian.org/debian bullseye-updates InRelease [44.0 kB
#  => => # ]
#  => => # Get:4 http://deb.debian.org/debian bullseye/main arm64 Packages [7955
#  => => # kB]
# [+] Building 2.7s (5/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 901B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.9s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/2] RUN apt-get update &&     apt-get install -y curl cowsay &&      1.8s
#  => => # Get:2 http://deb.debian.org/debian-security bullseye-security InReleas
#  => => # e [27.2 kB]
#  => => # Get:3 http://deb.debian.org/debian bullseye-updates InRelease [44.0 kB
#  => => # ]
#  => => # Get:4 http://deb.debian.org/debian bullseye/main arm64 Packages [7955
#  => => # kB]
# [+] Building 2.8s (5/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 901B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.9s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/2] RUN apt-get update &&     apt-get install -y curl cowsay &&      1.9s
#  => => # Get:2 http://deb.debian.org/debian-security bullseye-security InReleas
#  => => # e [27.2 kB]
#  => => # Get:3 http://deb.debian.org/debian bullseye-updates InRelease [44.0 kB
#  => => # ]
#  => => # Get:4 http://deb.debian.org/debian bullseye/main arm64 Packages [7955
#  => => # kB]
# [+] Building 2.9s (5/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 901B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.9s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/2] RUN apt-get update &&     apt-get install -y curl cowsay &&      2.0s
#  => => # Get:3 http://deb.debian.org/debian bullseye-updates InRelease [44.0 kB
#  => => # ]
#  => => # Get:4 http://deb.debian.org/debian bullseye/main arm64 Packages [7955
#  => => # kB]
#  => => # Get:5 http://deb.debian.org/debian-security bullseye-security/main arm
#  => => # 64 Packages [406 kB]
# [+] Building 3.0s (5/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 901B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.9s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/2] RUN apt-get update &&     apt-get install -y curl cowsay &&      2.1s
#  => => # Get:4 http://deb.debian.org/debian bullseye/main arm64 Packages [7955
#  => => # kB]
#  => => # Get:5 http://deb.debian.org/debian-security bullseye-security/main arm
#  => => # 64 Packages [406 kB]
#  => => # Get:6 http://deb.debian.org/debian bullseye-updates/main arm64 Package
#  => => # s [16.3 kB]
# [+] Building 3.2s (5/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 901B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.9s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/2] RUN apt-get update &&     apt-get install -y curl cowsay &&      2.3s
#  => => # Get:4 http://deb.debian.org/debian bullseye/main arm64 Packages [7955
#  => => # kB]
#  => => # Get:5 http://deb.debian.org/debian-security bullseye-security/main arm
#  => => # 64 Packages [406 kB]
#  => => # Get:6 http://deb.debian.org/debian bullseye-updates/main arm64 Package
#  => => # s [16.3 kB]
# [+] Building 3.4s (5/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 901B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.9s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/2] RUN apt-get update &&     apt-get install -y curl cowsay &&      2.4s
#  => => # Get:4 http://deb.debian.org/debian bullseye/main arm64 Packages [7955
#  => => # kB]
#  => => # Get:5 http://deb.debian.org/debian-security bullseye-security/main arm
#  => => # 64 Packages [406 kB]
#  => => # Get:6 http://deb.debian.org/debian bullseye-updates/main arm64 Package
#  => => # s [16.3 kB]
# [+] Building 3.4s (5/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 901B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.9s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/2] RUN apt-get update &&     apt-get install -y curl cowsay &&      2.5s
#  => => # Get:5 http://deb.debian.org/debian-security bullseye-security/main arm
#  => => # 64 Packages [406 kB]
#  => => # Get:6 http://deb.debian.org/debian bullseye-updates/main arm64 Package
#  => => # s [16.3 kB]
#  => => # Fetched 8523 kB in 2s (3526 kB/s)
#  => => # Reading package lists...
# [+] Building 3.6s (5/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 901B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.9s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/2] RUN apt-get update &&     apt-get install -y curl cowsay &&      2.7s
#  => => # Get:5 http://deb.debian.org/debian-security bullseye-security/main arm
#  => => # 64 Packages [406 kB]
#  => => # Get:6 http://deb.debian.org/debian bullseye-updates/main arm64 Package
#  => => # s [16.3 kB]
#  => => # Fetched 8523 kB in 2s (3526 kB/s)
#  => => # Reading package lists...
# [+] Building 3.6s (5/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 901B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.9s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/2] RUN apt-get update &&     apt-get install -y curl cowsay &&      2.7s
#  => => # Get:5 http://deb.debian.org/debian-security bullseye-security/main arm
#  => => # 64 Packages [406 kB]
#  => => # Get:6 http://deb.debian.org/debian bullseye-updates/main arm64 Package
#  => => # s [16.3 kB]
#  => => # Fetched 8523 kB in 2s (3526 kB/s)
#  => => # Reading package lists...
# [+] Building 3.8s (5/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 901B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.9s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/2] RUN apt-get update &&     apt-get install -y curl cowsay &&      2.8s
#  => => # 64 Packages [406 kB]
#  => => # Get:6 http://deb.debian.org/debian bullseye-updates/main arm64 Package
#  => => # s [16.3 kB]
#  => => # Fetched 8523 kB in 2s (3526 kB/s)
#  => => # Reading package lists...
#  => => # Reading package lists...
# [+] Building 3.8s (5/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 901B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.9s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/2] RUN apt-get update &&     apt-get install -y curl cowsay &&      2.9s
#  => => # 64 Packages [406 kB]
#  => => # Get:6 http://deb.debian.org/debian bullseye-updates/main arm64 Package
#  => => # s [16.3 kB]
#  => => # Fetched 8523 kB in 2s (3526 kB/s)
#  => => # Reading package lists...
#  => => # Reading package lists...
# [+] Building 4.0s (5/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 901B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.9s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/2] RUN apt-get update &&     apt-get install -y curl cowsay &&      3.0s
#  => => # mit
#  => => #   | libsasl2-modules-gssapi-heimdal libsasl2-modules-ldap libsasl2-mod
#  => => # ules-otp
#  => => #   libsasl2-modules-sql perl-doc libterm-readline-gnu-perl
#  => => #   | libterm-readline-perl-perl make libtap-harness-archive-perl
#  => => # The following NEW packages will be installed:
# [+] Building 4.2s (5/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 901B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.9s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/2] RUN apt-get update &&     apt-get install -y curl cowsay &&      3.2s
#  => => # suffix
#  => => # 0 upgraded, 23 newly installed, 0 to remove and 0 not upgraded.
#  => => # Need to get 10.1 MB of archives.
#  => => # After this operation, 53.1 MB of additional disk space will be used.
#  => => # Get:1 http://deb.debian.org/debian-security bullseye-security/main arm
#  => => # 64 perl-modules-5.32 all 5.32.1-4+deb11u4 [2824 kB]
# [+] Building 4.3s (5/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 901B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.9s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/2] RUN apt-get update &&     apt-get install -y curl cowsay &&      3.4s
#  => => # suffix
#  => => # 0 upgraded, 23 newly installed, 0 to remove and 0 not upgraded.
#  => => # Need to get 10.1 MB of archives.
#  => => # After this operation, 53.1 MB of additional disk space will be used.
#  => => # Get:1 http://deb.debian.org/debian-security bullseye-security/main arm
#  => => # 64 perl-modules-5.32 all 5.32.1-4+deb11u4 [2824 kB]
# [+] Building 4.5s (5/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 901B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.9s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/2] RUN apt-get update &&     apt-get install -y curl cowsay &&      3.5s
#  => => # suffix
#  => => # 0 upgraded, 23 newly installed, 0 to remove and 0 not upgraded.
#  => => # Need to get 10.1 MB of archives.
#  => => # After this operation, 53.1 MB of additional disk space will be used.
#  => => # Get:1 http://deb.debian.org/debian-security bullseye-security/main arm
#  => => # 64 perl-modules-5.32 all 5.32.1-4+deb11u4 [2824 kB]
# [+] Building 4.6s (5/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 901B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.9s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/2] RUN apt-get update &&     apt-get install -y curl cowsay &&      3.7s
#  => => # suffix
#  => => # 0 upgraded, 23 newly installed, 0 to remove and 0 not upgraded.
#  => => # Need to get 10.1 MB of archives.
#  => => # After this operation, 53.1 MB of additional disk space will be used.
#  => => # Get:1 http://deb.debian.org/debian-security bullseye-security/main arm
#  => => # 64 perl-modules-5.32 all 5.32.1-4+deb11u4 [2824 kB]
# [+] Building 4.8s (5/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 901B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.9s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/2] RUN apt-get update &&     apt-get install -y curl cowsay &&      3.8s
#  => => # suffix
#  => => # 0 upgraded, 23 newly installed, 0 to remove and 0 not upgraded.
#  => => # Need to get 10.1 MB of archives.
#  => => # After this operation, 53.1 MB of additional disk space will be used.
#  => => # Get:1 http://deb.debian.org/debian-security bullseye-security/main arm
#  => => # 64 perl-modules-5.32 all 5.32.1-4+deb11u4 [2824 kB]
# [+] Building 4.9s (5/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 901B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.9s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/2] RUN apt-get update &&     apt-get install -y curl cowsay &&      3.9s
#  => => # Need to get 10.1 MB of archives.
#  => => # After this operation, 53.1 MB of additional disk space will be used.
#  => => # Get:1 http://deb.debian.org/debian-security bullseye-security/main arm
#  => => # 64 perl-modules-5.32 all 5.32.1-4+deb11u4 [2824 kB]
#  => => # Get:2 http://deb.debian.org/debian bullseye/main arm64 libgdbm6 arm64
#  => => # 1.19-2 [64.0 kB]
# [+] Building 5.1s (5/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 901B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.9s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/2] RUN apt-get update &&     apt-get install -y curl cowsay &&      4.2s
#  => => # Get:2 http://deb.debian.org/debian bullseye/main arm64 libgdbm6 arm64
#  => => # 1.19-2 [64.0 kB]
#  => => # Get:3 http://deb.debian.org/debian bullseye/main arm64 libgdbm-compat4
#  => => #  arm64 1.19-2 [44.6 kB]
#  => => # Get:4 http://deb.debian.org/debian-security bullseye-security/main arm
#  => => # 64 libperl5.32 arm64 5.32.1-4+deb11u4 [3917 kB]
# [+] Building 5.3s (5/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 901B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.9s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/2] RUN apt-get update &&     apt-get install -y curl cowsay &&      4.3s
#  => => # Get:2 http://deb.debian.org/debian bullseye/main arm64 libgdbm6 arm64
#  => => # 1.19-2 [64.0 kB]
#  => => # Get:3 http://deb.debian.org/debian bullseye/main arm64 libgdbm-compat4
#  => => #  arm64 1.19-2 [44.6 kB]
#  => => # Get:4 http://deb.debian.org/debian-security bullseye-security/main arm
#  => => # 64 libperl5.32 arm64 5.32.1-4+deb11u4 [3917 kB]
# [+] Building 5.4s (5/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 901B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.9s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/2] RUN apt-get update &&     apt-get install -y curl cowsay &&      4.5s
#  => => # Get:2 http://deb.debian.org/debian bullseye/main arm64 libgdbm6 arm64
#  => => # 1.19-2 [64.0 kB]
#  => => # Get:3 http://deb.debian.org/debian bullseye/main arm64 libgdbm-compat4
#  => => #  arm64 1.19-2 [44.6 kB]
#  => => # Get:4 http://deb.debian.org/debian-security bullseye-security/main arm
#  => => # 64 libperl5.32 arm64 5.32.1-4+deb11u4 [3917 kB]
# [+] Building 5.6s (5/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 901B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.9s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/2] RUN apt-get update &&     apt-get install -y curl cowsay &&      4.6s
#  => => # Get:2 http://deb.debian.org/debian bullseye/main arm64 libgdbm6 arm64
#  => => # 1.19-2 [64.0 kB]
#  => => # Get:3 http://deb.debian.org/debian bullseye/main arm64 libgdbm-compat4
#  => => #  arm64 1.19-2 [44.6 kB]
#  => => # Get:4 http://deb.debian.org/debian-security bullseye-security/main arm
#  => => # 64 libperl5.32 arm64 5.32.1-4+deb11u4 [3917 kB]
# [+] Building 5.7s (5/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 901B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.9s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/2] RUN apt-get update &&     apt-get install -y curl cowsay &&      4.8s
#  => => # Get:2 http://deb.debian.org/debian bullseye/main arm64 libgdbm6 arm64
#  => => # 1.19-2 [64.0 kB]
#  => => # Get:3 http://deb.debian.org/debian bullseye/main arm64 libgdbm-compat4
#  => => #  arm64 1.19-2 [44.6 kB]
#  => => # Get:4 http://deb.debian.org/debian-security bullseye-security/main arm
#  => => # 64 libperl5.32 arm64 5.32.1-4+deb11u4 [3917 kB]
# [+] Building 5.9s (5/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 901B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.9s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/2] RUN apt-get update &&     apt-get install -y curl cowsay &&      4.9s
#  => => # Get:2 http://deb.debian.org/debian bullseye/main arm64 libgdbm6 arm64
#  => => # 1.19-2 [64.0 kB]
#  => => # Get:3 http://deb.debian.org/debian bullseye/main arm64 libgdbm-compat4
#  => => #  arm64 1.19-2 [44.6 kB]
#  => => # Get:4 http://deb.debian.org/debian-security bullseye-security/main arm
#  => => # 64 libperl5.32 arm64 5.32.1-4+deb11u4 [3917 kB]
# [+] Building 6.0s (5/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 901B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.9s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
# ...
#  => => # Setting up libldap-2.4-2:arm64 (2.4.57+dfsg-3+deb11u1) ...
#  => => # Setting up ca-certificates (20210119) ...
#  => => # debconf: unable to initialize frontend: Dialog
#  => => # debconf: (TERM is not set, so the dialog frontend is not usable.)
#  => => # debconf: falling back to frontend: Readline
#  => => # Updating certificates in /etc/ssl/certs...
# [+] Building 7.8s (5/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 901B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.9s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/2] RUN apt-get update &&     apt-get install -y curl cowsay &&      6.9s
#  => => # Setting up libldap-2.4-2:arm64 (2.4.57+dfsg-3+deb11u1) ...
#  => => # Setting up ca-certificates (20210119) ...
#  => => # debconf: unable to initialize frontend: Dialog
#  => => # debconf: (TERM is not set, so the dialog frontend is not usable.)
#  => => # debconf: falling back to frontend: Readline
#  => => # Updating certificates in /etc/ssl/certs...
# [+] Building 7.8s (5/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 901B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.9s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/2] RUN apt-get update &&     apt-get install -y curl cowsay &&      6.9s
#  => => # Setting up ca-certificates (20210119) ...
#  => => # debconf: unable to initialize frontend: Dialog
#  => => # debconf: (TERM is not set, so the dialog frontend is not usable.)
#  => => # debconf: falling back to frontend: Readline
#  => => # Updating certificates in /etc/ssl/certs...
#  => => # 129 added, 0 removed; done.
# [+] Building 8.0s (5/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 901B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.9s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/2] RUN apt-get update &&     apt-get install -y curl cowsay &&      7.1s
#  => => # Setting up cowsay (3.03+dfsg2-8) ...
#  => => # Processing triggers for libc-bin (2.31-13+deb11u13) ...
#  => => # Processing triggers for ca-certificates (20210119) ...
#  => => # Updating certificates in /etc/ssl/certs...
#  => => # 0 added, 0 removed; done.
#  => => # Running hooks in /etc/ca-certificates/update.d...
# [+] Building 8.2s (6/7)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 901B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.9s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/2] RUN apt-get update &&     apt-get install -y curl cowsay &&      7.1s
#  => exporting to image                                                     0.2s
#  => => exporting layers                                                    0.2s
#
#
#
#
# [+] Building 8.4s (6/7)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 901B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.9s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/2] RUN apt-get update &&     apt-get install -y curl cowsay &&      7.1s
#  => exporting to image                                                     0.3s
#  => => exporting layers                                                    0.3s
# [+] Building 8.5s (6/7)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 901B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.9s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/2] RUN apt-get update &&     apt-get install -y curl cowsay &&      7.1s
#  => exporting to image                                                     0.5s
#  => => exporting layers                                                    0.5s
# [+] Building 8.7s (6/7)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 901B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.9s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/2] RUN apt-get update &&     apt-get install -y curl cowsay &&      7.1s
#  => exporting to image                                                     0.6s
#  => => exporting layers                                                    0.6s
# [+] Building 8.8s (6/7)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 901B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.9s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/2] RUN apt-get update &&     apt-get install -y curl cowsay &&      7.1s
#  => exporting to image                                                     0.8s
#  => => exporting layers                                                    0.8s
# [+] Building 9.0s (6/7)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 901B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.9s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/2] RUN apt-get update &&     apt-get install -y curl cowsay &&      7.1s
#  => exporting to image                                                     0.9s
#  => => exporting layers                                                    0.9s
# [+] Building 9.1s (6/7)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 901B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.9s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/2] RUN apt-get update &&     apt-get install -y curl cowsay &&      7.1s
#  => exporting to image                                                     1.0s
#  => => exporting layers                                                    1.0s
# [+] Building 9.3s (6/7)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 901B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.9s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/2] RUN apt-get update &&     apt-get install -y curl cowsay &&      7.1s
#  => exporting to image                                                     1.2s
#  => => exporting layers                                                    1.0s
#  => => exporting manifest sha256:1d880326bfa15ed16af973f793407a7b011af2b7  0.0s
#  => => exporting config sha256:c66a7412a91379e019d81a4e4998884a1b5b7f2a09  0.0s
#  => => exporting attestation manifest sha256:47a4f718de7f915d1839aaf4b1f8  0.0s
#  => => exporting manifest list sha256:5aac37c507552b0d9928886062f95c6f4b9  0.0s
#  => => naming to docker.io/library/cowshoutimage:latest                    0.0s
#  => => unpacking to docker.io/library/cowshoutimage:latest                 0.2s
# [+] Building 9.3s (6/7)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 901B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.9s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/2] RUN apt-get update &&     apt-get install -y curl cowsay &&      7.1s
#  => exporting to image                                                     1.2s
#  => => exporting layers                                                    1.0s
#  => => exporting manifest sha256:1d880326bfa15ed16af973f793407a7b011af2b7  0.0s
#  => => exporting config sha256:c66a7412a91379e019d81a4e4998884a1b5b7f2a09  0.0s
#  => => exporting attestation manifest sha256:47a4f718de7f915d1839aaf4b1f8  0.0s
#  => => exporting manifest list sha256:5aac37c507552b0d9928886062f95c6f4b9  0.0s
#  => => naming to docker.io/library/cowshoutimage:latest                    0.0s
#  => => unpacking to docker.io/library/cowshoutimage:latest                 0.2s
# [+] Building 9.3s (7/7) FINISHED                           docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 901B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.9s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/2] RUN apt-get update &&     apt-get install -y curl cowsay &&      7.1s
#  => exporting to image                                                     1.2s
#  => => exporting layers                                                    1.0s
#  => => exporting manifest sha256:1d880326bfa15ed16af973f793407a7b011af2b7  0.0s
#  => => exporting config sha256:c66a7412a91379e019d81a4e4998884a1b5b7f2a09  0.0s
#  => => exporting attestation manifest sha256:47a4f718de7f915d1839aaf4b1f8  0.0s
#  => => exporting manifest list sha256:5aac37c507552b0d9928886062f95c6f4b9  0.0s
#  => => naming to docker.io/library/cowshoutimage:latest                    0.0s
#  => => unpacking to docker.io/library/cowshoutimage:latest                 0.2s
#
#  2 warnings found (use docker --debug to expand):
#  - LegacyKeyValueFormat: "LABEL key=value" should be used instead of legacy "LABEL key value" format (line 5)
#  - LegacyKeyValueFormat: "LABEL key=value" should be used instead of legacy "LABEL key value" format (line 6)

# %%
# make sure that the image has been built
# !docker images
# Out:
# REPOSITORY                                                 TAG                        IMAGE ID       CREATED          SIZE
# cowshoutimage                                              latest                     5aac37c50755   29 seconds ago   188MB
# hello-world                                                latest                     54e66cc1dd1f   7 weeks ago      16.9kB
# community.wave.seqera.io/library/fastqc                    0.12.1--af7a5314d5015c29   b7f6caf35926   11 months ago    1.37GB
# quay.io/biocontainers/fq                                   0.12.0--h9ee0642_0         74b59572f1d0   14 months ago    20MB
# quay.io/biocontainers/r-shinyngs                           1.8.8--r43hdfd78af_0       e0de72408557   17 months ago    1.99GB
# quay.io/biocontainers/atlas-gene-annotation-manipulation   1.1.1--hdfd78af_0          099d0e113ec8   18 months ago    1.82GB
# quay.io/nf-core/ubuntu                                     20.04                      59e9d08d8dc1   2 years ago      110MB
# quay.io/biocontainers/pandas                               1.5.2                      cbb54fcf8730   2 years ago      493MB
# quay.io/biocontainers/gsea                                 4.3.2--hdfd78af_0          0010041fff53   2 years ago      849MB
# quay.io/biocontainers/r-base                               4.2.1                      6721ee8bfba2   2 years ago      1.17GB
# quay.io/biocontainers/p7zip                                16.02                      731aaeef376a   3 years ago      47.7MB
# quay.io/biocontainers/python                               3.9--1                     d97d2b329b4e   4 years ago      275MB
# quay.io/biocontainers/gawk                                 5.1.0                      9d300f3d0a35   5 years ago      53.4MB
# quay.io/biocontainers/bioconductor-deseq2                  1.34.0--r41hc247a5b_3      c06884d353ef   55 years ago     452MB
# quay.io/biocontainers/wget                                 1.20.1                     7e5ba9e87a25   55 years ago     26.9MB

# %%
# run the docker file 
# !docker run --rm cowshoutimage cowsay "Is it running though?!"
# Out:
#  ________________________
# < Is it running though?! >
#  ------------------------
#         \   ^__^
#          \  (oo)\_______
#             (__)\       )\/\
#                 ||----w |
#                 ||     ||

# %% [markdown]
# ## Let's do some bioinformatics with the docker file and create a new docker file that holds the salmon tool used in rnaseq
#
# To do so, use "curl" in your new dockerfile to get salmon from https://github.com/COMBINE-lab/salmon/releases/download/v1.5.2/salmon-1.5.2_linux_x86_64.tar.gz

# %%
# use the file "salmon_docker" in this directory to build a new docker image
# !docker build -t salmon_docker -f /Users/peterbrederlow/Documents/Uni/MasterBioinformatik/SS25/WorkflowCourse/computational-workflows-2025/notebooks/day_03_part2/salmon_docker .
# Out:
# [+] Building 0.0s (0/1)                                    docker:desktop-linux
# [+] Building 0.0s (1/1) FINISHED                           docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 796B                                       0.0s
# salmon_docker:18
# --------------------
#   16 |         mv salmon-${SALMON_VERSION}_linux_x86_64/bin/salmon /usr/local/bin/ && \
#   17 |         rm -rf salmon.tar.gz salmon-${SALMON_VERSION}_linux_x86_64
#   18 | >>>     --platform linux/amd64
#   19 |
#   20 |     # Set the PATH environment variable (to /usr/bin)
# --------------------
# ERROR: failed to build: failed to solve: dockerfile parse error on line 18: unknown instruction: --platform

# %%
# !docker run --interactive -t salmon_docker bash
# Out:
# root@b85b14d58c04:/# ^C
#
# root@b85b14d58c04:/#

# %%
# run the docker image to give out the version of salmon
# !docker run --rm salmon_docker

# %% [markdown]
# ## Do you think bioinformaticians have to create a docker image every time they want to run a tool?
#
# Find the salmon docker image online and run it on your computer.
#
# What is https://biocontainers.pro/ ?

# %% [markdown]
# ## Are there other ways to create Docker (or Apptainer) images?
#
# What is https://seqera.io/containers/ ?
